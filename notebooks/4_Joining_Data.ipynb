# %% [markdown]
# # Modelling

# %%
import pandas as pd
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine
import matplotlib as plt
import pickle
import os

# %%
DATA_DIR = '../data'

# %% [markdown]
# ## Load Target

# %%
race_winner = pickle.load(open(os.path.join(DATA_DIR, 'race_winner.p'), 'rb'))
race_winner
# Out:
#          winning_box
# race_id
# 2539775            3
# 2851623            5
# 2539776            3
# 2851624            4
# 2539777            1
# ...              ...
# 2539770            1
# 2539771            4
# 2539772            2
# 2539773            1
# 2539774            6
#
# [54210 rows x 1 columns]

# %% [markdown]
# # Load Filters

# %%
runners_6 = pickle.load(open(os.path.join(DATA_DIR, 'runners_6.p'), 'rb'))
runners_6
# Out:
# Empty DataFrame
# Columns: []
# Index: [16022, 16809, 16895, 16896, 16897, 16898, 16899, 16900, 16925, 16926, 16927, 17003, 17004, 17005, 17006, 17007, 17008, 17009, 17010, 17199, 17202, 17206, 17207, 17212, 17349, 17350, 17774, 17775, 17776, 18723, 19046, 19047, 19139, 19150, 19153, 20428, 20429, 20564, 20565, 20745, 20870, 20976, 20977, 21069, 21196, 21197, 21305, 21306, 21435, 21560, 21561, 21562, 21687, 21688, 21689, 21690, 21787, 21788, 21789, 21790, 21791, 21792, 21875, 21876, 21877, 21917, 21918, 21919, 22027, 22028, 22769, 22992, 22993, 22994, 22995, 23269, 23618, 23619, 23620, 23688, 23689, 24144, 24145, 24146, 24199, 24211, 24214, 24308, 24309, 24400, 24479, 24480, 24481, 31628, 31629, 31689, 31691, 31693, 31833, 31836, ...]
#
# [52384 rows x 0 columns]

# %%
grade = pickle.load(open(os.path.join(DATA_DIR, 'grade.p'), 'rb'))
grade
# Out:
#                         date_time
# race_id
# 2539774 2008-11-15 20:58:00+00:00
# 2539775 2008-11-15 21:14:00+00:00
# 2851623 2010-08-30 10:07:00+00:00
# 2851624 2010-08-30 10:23:00+00:00
# 2539777 2008-11-15 21:45:00+00:00
# ...                           ...
# 2539765 2008-11-15 18:38:00+00:00
# 2539766 2008-11-15 18:56:00+00:00
# 2539767 2008-11-15 19:11:00+00:00
# 2539769 2008-11-15 19:42:00+00:00
# 2539770 2008-11-15 19:58:00+00:00
#
# [42078 rows x 1 columns]

# %% [markdown]
# ## Load Benchmark

# %%
benchmark = pickle.load(open(os.path.join(DATA_DIR, 'benchmark.p'), 'rb'))
benchmark
# Out:
#          benchmark
# race_id
# 16022            1
# 16809            2
# 16895            4
# 16896            5
# 16897            2
# ...            ...
# 4642020          4
# 4642021          3
# 4642022          6
# 4642023          3
# 4642024          1
#
# [53973 rows x 1 columns]

# %% [markdown]
# ## Load Features

# %%
features_dict = pickle.load(open(os.path.join(DATA_DIR, 'features_dict_25days.p'), 'rb'))
features_list = features_dict['features']
no_qual_races = features_dict['no_qual_races']

# %% [markdown]
# # Join Features

# %%
starting_point = grade.merge(runners_6, left_index = True, right_index = True)
starting_point = starting_point.merge(race_winner, left_index = True, right_index = True)
starting_point = starting_point.merge(benchmark, left_index = True, right_index = True)
starting_point
# Out:
#                         date_time  winning_box  benchmark
# race_id
# 2539774 2008-11-15 20:58:00+00:00            6          3
# 2539775 2008-11-15 21:14:00+00:00            3          2
# 2851623 2010-08-30 10:07:00+00:00            5          6
# 2851624 2010-08-30 10:23:00+00:00            4          5
# 2539777 2008-11-15 21:45:00+00:00            1          2
# ...                           ...          ...        ...
# 2539765 2008-11-15 18:38:00+00:00            1          6
# 2539766 2008-11-15 18:56:00+00:00            4          3
# 2539767 2008-11-15 19:11:00+00:00            6          6
# 2539769 2008-11-15 19:42:00+00:00            6          4
# 2539770 2008-11-15 19:58:00+00:00            1          6
#
# [40648 rows x 3 columns]

# %%
modelling_data = starting_point.copy()
for features in features_list:
    modelling_data = modelling_data.merge(features, left_index = True, right_index = True)
modelling_data
# Out:
#                         date_time  winning_box  benchmark  min_time_1  \
# race_id
# 2539774 2008-11-15 20:58:00+00:00            6          3       29.08
# 2539775 2008-11-15 21:14:00+00:00            3          2       29.11
# 2851623 2010-08-30 10:07:00+00:00            5          6       30.02
# 2851624 2010-08-30 10:23:00+00:00            4          5       29.99
# 2539777 2008-11-15 21:45:00+00:00            1          2         NaN
# ...                           ...          ...        ...         ...
# 2539765 2008-11-15 18:38:00+00:00            1          6       28.85
# 2539766 2008-11-15 18:56:00+00:00            4          3       28.89
# 2539767 2008-11-15 19:11:00+00:00            6          6       29.65
# 2539769 2008-11-15 19:42:00+00:00            6          4       29.30
# 2539770 2008-11-15 19:58:00+00:00            1          6       29.19
#
#          min_time_2  min_time_3  min_time_4  min_time_5  min_time_6  \
# race_id
# 2539774       28.95       29.13       28.89       28.76       29.74
# 2539775       29.10       29.25       29.13       29.10       29.02
# 2851623       29.95       30.74       30.23       29.84       29.78
# 2851624       30.11       30.11       29.53       29.71       29.71
# 2539777         NaN       31.08         NaN       30.32       29.47
# ...             ...         ...         ...         ...         ...
# 2539765       29.00       29.13       29.10       29.50       28.87
# 2539766       29.44       29.55       29.43       29.67       29.04
# 2539767       29.71       30.10       29.52       29.95       29.56
# 2539769       28.98         NaN       28.99       29.52       29.57
# 2539770       29.52       29.02       29.13       29.33       29.07
#
#          avg_time_1  ...  pcnt_place_3  pcnt_place_4  pcnt_place_5  \
# race_id              ...
# 2539774   29.176667  ...           0.5      0.500000           1.0
# 2539775   29.120000  ...           0.0      0.500000           0.0
# 2851623   30.415000  ...           0.0      0.000000           0.5
# 2851624   30.117500  ...           0.0      0.666667           1.0
# 2539777         NaN  ...           0.0           NaN           0.0
# ...             ...  ...           ...           ...           ...
# 2539765   28.865000  ...           0.5      0.500000           0.0
# 2539766   29.193333  ...           0.0      0.000000           0.0
# 2539767   29.890000  ...           0.5      0.500000           0.0
# 2539769   29.300000  ...           NaN      0.666667           0.0
# 2539770   29.190000  ...           1.0      0.000000           0.0
#
#          pcnt_place_6  pcnt_show_1  pcnt_show_2  pcnt_show_3  pcnt_show_4  \
# race_id
# 2539774      0.000000     0.666667     1.000000     0.500000     0.500000
# 2539775      0.333333     0.333333     1.000000     0.666667     0.500000
# 2851623      0.333333     0.500000     0.000000     0.000000     0.000000
# 2851624      0.666667     0.000000     0.000000     0.000000     0.666667
# 2539777      1.000000          NaN          NaN     0.000000          NaN
# ...               ...          ...          ...          ...          ...
# 2539765      0.333333     1.000000     0.666667     0.500000     0.750000
# 2539766      0.500000     1.000000     0.000000     0.000000     0.000000
# 2539767      0.333333     0.333333     0.500000     0.750000     0.500000
# 2539769      0.000000     1.000000     0.500000          NaN     1.000000
# 2539770      1.000000     1.000000     0.000000     1.000000     0.333333
#
#          pcnt_show_5  pcnt_show_6
# race_id
# 2539774          1.0     0.000000
# 2539775          0.0     0.666667
# 2851623          0.5     1.000000
# 2851624          1.0     0.666667
# 2539777          0.0     1.000000
# ...              ...          ...
# 2539765          0.0     0.333333
# 2539766          0.0     0.500000
# 2539767          0.0     0.666667
# 2539769          0.0     0.666667
# 2539770          1.0     1.000000
#
# [40648 rows x 51 columns]

# %%
# check columns
modelling_data.columns.values
# Out:
# array(['date_time', 'winning_box', 'benchmark', 'min_time_1',
#        'min_time_2', 'min_time_3', 'min_time_4', 'min_time_5',
#        'min_time_6', 'avg_time_1', 'avg_time_2', 'avg_time_3',
#        'avg_time_4', 'avg_time_5', 'avg_time_6', 'min_stime_1',
#        'min_stime_2', 'min_stime_3', 'min_stime_4', 'min_stime_5',
#        'min_stime_6', 'avg_stime_1', 'avg_stime_2', 'avg_stime_3',
#        'avg_stime_4', 'avg_stime_5', 'avg_stime_6', 'avg_fin_1',
#        'avg_fin_2', 'avg_fin_3', 'avg_fin_4', 'avg_fin_5', 'avg_fin_6',
#        'pcnt_win_1', 'pcnt_win_2', 'pcnt_win_3', 'pcnt_win_4',
#        'pcnt_win_5', 'pcnt_win_6', 'pcnt_place_1', 'pcnt_place_2',
#        'pcnt_place_3', 'pcnt_place_4', 'pcnt_place_5', 'pcnt_place_6',
#        'pcnt_show_1', 'pcnt_show_2', 'pcnt_show_3', 'pcnt_show_4',
#        'pcnt_show_5', 'pcnt_show_6'], dtype=object)

# %%
# target must start from 0
modelling_data['winning_box'] = modelling_data['winning_box'] - 1
modelling_data['benchmark'] = modelling_data['benchmark'] - 1

# %% [markdown]
# # Store Modelling data

# %%
modelling_data.to_csv(os.path.join(DATA_DIR, 'modelling_data_25days.csv'))
